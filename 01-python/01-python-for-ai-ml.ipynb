# %% [markdown]
# # Day 01 — Starting My AI/ML Journey

# %%
print("Hello AI/ML!")
# Out:
# Hello AI/ML!

# %% [markdown]
# # Why am I changing from web development to AI/ML?
# I am learning Artificial Intelligence and Machine Learning because I want to transition my career from web development into the AI/ML field.
#
# I already have a background in Computer Science/Information Systems and experience with software and web development. Instead of throwing away those skills, I want to combine them with AI and machine learning.
#
# My long-term goal is to become an
# **AI/ML Engineer** who can understand machine learning concepts, build models, develop AI applications, and deploy them as real-world software.
#
# I also want to understand how modern AI systems work rather than only using AI tools and APIs.
#
# My learning goals are:
#
# 1. Learn Python for AI/ML.
# 2. Understand mathematics and statistics needed for ML.
# 3. Learn classical machine learning.
# 4. Learn deep learning.
# 5. Learn PyTorch.
# 6. Understand NLP and computer vision.
# 7. Learn Transformers and LLMs.
# 8. Build RAG and generative AI applications.
# 9. Learn how to deploy AI systems.
# 10. Build real-world projects.
# 11. Document my learning publicly through GitHub and learning posts.

# %% [markdown]
# ## 2. My current skills
# My current background is in Computer Science / Information Systems, and I have experience with web development.
# **Skills I already have**
# - Programming fundamentals
# - Computer science fundamentals
# - Web development
# - Frontend development
# - Backend development
# - Databases
# - APIs
# - Git/GitHub
# - Software development concepts
# - Problem solving
#
# <br>
# **Skills I need to improve for AI/ML**
# - Python for data science
# - NumPy
# - Pandas
# - Data visualization
# - Probability
# - Statistics
# - Linear algebra
# - Calculus
# - Machine learning
# - Scikit-learn
# - Deep learning
# - PyTorch
# - NLP
# - Computer vision
# - Transformers
# - LLMs
# - RAG
# - Model deployment
# - MLOps
#
# I don't need to forget my web-development skills. I want to combine software engineering with AI/ML.

# %% [markdown]
# ## 3. My AI/ML roadmap
# My planned learning path is:
# # AI/ML Engineer Roadmap
#
# **Python**<br>
# ↓<br>
# **NumPy + Pandas + Data Visualization**<br>
# ↓<br>
# **Mathematics + Statistics**<br>
# ↓<br>
# **Machine Learning Fundamentals**<br>
# ↓<br>
# **Scikit-learn**<br>
# ↓<br>
# **Machine Learning Projects**<br>
# ↓<br>
# **Deep Learning**<br>
# ↓<br>
# **PyTorch**<br>
# ↓<br>
# **NLP / Computer Vision**<br>
# ↓<br>
# **Transformers**<br>
# ↓<br>
# **LLMs**<br>
# ↓<br>
# **RAG + Generative AI**<br>
# ↓<br>
# **AI Application Development**<br>
# ↓<br>
# **Deployment + MLOps**<br>
# ↓<br>
# **Real-world AI Projects**<br>
# ↓<br>
# # AI/ML Engineer
# I will learn these subjects progressively rather than trying to learn everything at the same time.

# %% [markdown]
# ## 4. What is Artificial Intelligence?
# **Artificial Intelligence (AI)** is a broad field of computer science focused on creating computer systems that can perform tasks that normally require some form of human intelligence.

# %% [markdown]
# ## 5. What is Machine Learning?

# %% [markdown]
# ## 6. What is Deep Learning?

# %% [markdown]
# ## 7. Why Python is important for AI/ML

# %% [markdown]
# ## 8. My first Python experiments

# %% [markdown]
# ## 9. What I learned today

# %% [markdown]
# ## 10. What confused me?

# %% [markdown]
# ## 11. Questions for tomorrow

# %% [markdown]
# ## 12. Resources
