# %% [markdown]
# # Day 01 — Starting My AI/ML Journey

# %%
print("Hello AI/ML!")
# Out:
# Hello AI/ML!

# %% [markdown]
# # Why am I changing from web development to AI/ML?
# I want to learn AI and Machine Learning for:
# 1. to know how an AI Machine work

# %% [markdown]
# ## 2. My current skills

# %% [markdown]
# ## 3. My AI/ML roadmap

# %% [markdown]
# ## 4. What is Artificial Intelligence?

# %% [markdown]
# ## 5. What is Machine Learning?

# %% [markdown]
# ## 6. What is Deep Learning?

# %% [markdown]
# ## 7. Why Python is important for AI/ML

# %% [markdown]
# ## 8. My first Python experiments

# %% [markdown]
# ## 9. What I learned today

# %% [markdown]
# ## 10. What confused me?

# %% [markdown]
# ## 11. Questions for tomorrow

# %% [markdown]
# ## 12. Resources
